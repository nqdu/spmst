# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt = 0.04
n = 1024
t = np.arange(n) * dt 
freqs = np.fft.rfftfreq(n,dt)
r0 = 1.0 
delta = 2.0
H = 1 + r0 * np.exp(-1j * 2 * np.pi * freqs * delta)
plt.plot(freqs,abs(H))
